# %% [markdown]
# ![Vinho-Tinto-e-Vinho-Branco-3.jpg](attachment:Vinho-Tinto-e-Vinho-Branco-3.jpg)

# %% [markdown]
# <a name="índice"></a>
# # Índice
# [Extra Trees Classifier](#etc)<br>
# [Multi-layer Perceptron (MLP)](#rna)

# %% [markdown]
# # BUSINESS UNDERSTANDING

# %%
# Case de dados para CLASSIFICAÇÃO
# Identificar o tipo de vinho de acordo com as características de vinho tinto e branco presente na base de dados

# %% [markdown]
# # DATA UNDERSTANDING

# %%
# IA -> MACHINE LEARNING
# MODELO SUPERVISIONADO -> MÉTODO CLASSIFICAÇÃO
# Dados disponibilizadas no kaggle para efeito de estudo sobre o tipo de vinho com base nas características
# Obs1: Verificar se todos os atributos são importantes para o modelo

# %% [markdown]
# [Wine dataset](https://www.kaggle.com/datasets/dell4010/wine-dataset)

# %% [markdown]
# # Title

# %%
# Classificação de binhos tinto e branco

# %% [markdown]
# # Head

# %%
# estudando machine learning
# by geanclm em 20/02/2022 at 11:47h
# update by geanclm on 24/10/2023

# %% [markdown]
# # Local files

# %%
# !dir
# Out:
#  O volume na unidade C ‚ Windows
#  O N£mero de S‚rie do Volume ‚ 9241-82D4
#
#  Pasta de C:\Users\geanc\OneDrive\Documentos\GitHub\machine-learning
#
# 15/12/2023  19:54    <DIR>          .
# 15/12/2023  13:52    <DIR>          ..
# 24/10/2023  09:36                68 .gitattributes
# 29/11/2023  09:27    <DIR>          .ipynb_checkpoints
# 15/12/2023  19:54         1.173.449 CLASSIFICA€ÇO_Wine_Kaggle_csv.ipynb
# 24/10/2023  09:36             1.091 LICENSE
# 24/10/2023  09:36                50 README.md
# 01/11/2023  13:01           131.951 Vinho-Tinto-e-Vinho-Branco.jpg
# 07/11/2023  16:35         9.618.537 wine_classifier_etc_2023-11-07.joblib
# 24/10/2023  09:36           384.016 wine_dataset.csv
#                7 arquivo(s)     11.309.162 bytes
#                3 pasta(s)   847.508.754.432 bytes dispon¡veis

# %% [markdown]
# # Library installation

# %%
# !pip install -U imbalanced-learn
# !pip install imblearn
# !pip install pyod
# !pip install tensorflow

# %% [markdown]
# # Import libs

# %%
# para verificar dados relativos a versão utilizada
import sys
import sklearn

# função utilizada para registrar data e hora no nome do modelo salvo
from datetime import datetime

# principais bibliotecas para lidar com dados
import pandas as pd
import numpy as np

# gerar gráficos
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import plot_tree # Gráfico da Árvore

# função para gerar o MODELO de machine learning
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# trabalhar com os dados com rede neural
from sklearn.neural_network import MLPClassifier
import tensorflow as tf

# Validação cruzada
from sklearn.model_selection import GridSearchCV

# função para MÉTRICA de validação do modelo
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve, auc

# função para VALIDAÇÃO do modelo
from sklearn.model_selection import train_test_split as tts

# balancemaneto dos dados em relação ao MAIOR valor de y
# from imblearn import under_sampling, over_sampling # verificar se realmente é necessária essa linha - reduntante!!!
from imblearn.over_sampling import SMOTE

# balancemaneto dos dados em relação ao MENOR valor de y
from imblearn.under_sampling import RandomUnderSampler

# Padronizar os dados
from sklearn.preprocessing import StandardScaler

# Normalizar os dados
from sklearn.preprocessing import MinMaxScaler

# biblioteca para persistir o modelo
import joblib

# identificar outliers
from pyod.models.knn import KNN

# Configuração da Validação Cruzada
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
# from sklearn.model_selection import RepeatedStratifiedKFold

# Combinação dos modelos
from sklearn.ensemble import VotingClassifier

# %%
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %%
print(sklearn.__version__)
# Out:
# 1.2.2

# %% [markdown]
# # Load data

# %%
df = pd.read_csv(r'C:\Users\geanc\OneDrive\Documentos\GitHub\machine-learning\wine_dataset.csv')

# %% [markdown]
# # Exploratory Analysis

# %%
df.sample(15).T
# Out:
#                          6182    2079    984     409      4591     1499  \
# fixed_acidity             6.4     6.7    12.2    12.5      6.6      6.9
# volatile_acidity         0.23    0.47    0.45    0.46      0.2     0.74
# citric_acid              0.37    0.34    0.49    0.49     0.27     0.03
# residual_sugar            7.9     8.9     1.4     4.5     10.9      2.3
# chlorides                0.05   0.043   0.075    0.07    0.038    0.054
# free_sulfur_dioxide      60.0    31.0     3.0    26.0     29.0      7.0
# total_sulfur_dioxide    150.0   172.0     6.0    49.0    130.0     16.0
# density               0.99488  0.9964  0.9969  0.9981  0.99496  0.99508
# pH                       2.86    3.22    3.13    3.05     3.11     3.45
# sulphates                0.49     0.6    0.63    0.57     0.44     0.63
# alcohol                   9.3     9.2    10.4     9.6     10.5     11.5
# quality                     6       5       5       4        7        6
# style                   white   white     red     red    white      red
#
#                          6420     819      5502    5598    2992     5970  \
# fixed_acidity             7.0      9.1      5.8     6.4     5.7      7.0
# volatile_acidity         0.24     0.66     0.27    0.24   0.135     0.23
# citric_acid              0.47     0.15     0.26    0.49     0.3     0.28
# residual_sugar            1.3      3.2      3.5     5.8     4.6      2.7
# chlorides               0.043    0.097    0.071   0.053   0.042    0.053
# free_sulfur_dioxide      18.0      9.0     26.0    25.0    19.0     16.0
# total_sulfur_dioxide    131.0     59.0     69.0   120.0   101.0     92.0
# density               0.99176  0.99976  0.98994  0.9942  0.9946  0.99372
# pH                       3.19     3.28      3.1    3.01    3.31     3.18
# sulphates                0.45     0.54     0.38    0.98    0.42     0.56
# alcohol                  11.0      9.6     11.5    10.5     9.3      9.3
# quality                     6        5        6       6       6        5
# style                   white      red    white   white   white    white
#
#                         3248    1640    3235
# fixed_acidity            6.9     6.7     7.8
# volatile_acidity        0.26    0.24    0.49
# citric_acid             0.49    0.39    0.49
# residual_sugar           1.6     2.9     7.0
# chlorides              0.058   0.173   0.043
# free_sulfur_dioxide     39.0    63.0    29.0
# total_sulfur_dioxide   166.0   157.0   149.0
# density               0.9965  0.9937  0.9952
# pH                      3.65     3.1    3.21
# sulphates               0.52    0.34    0.33
# alcohol                  9.4     9.4    10.0
# quality                    4       6       5
# style                  white   white   white

# %%
# filtrar dado específico do data frame
df.loc[0:4,'style']
# Out:
# 0    red
# 1    red
# 2    red
# 3    red
# 4    red
# Name: style, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  style                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.dtypes[df.dtypes.values == 'object'].index
# Out:
# Index(['style'], dtype='object')

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed_acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile_acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric_acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual_sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free_sulfur_dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total_sulfur_dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
#                             50%        75%        max
# fixed_acidity           7.00000    7.70000   15.90000
# volatile_acidity        0.29000    0.40000    1.58000
# citric_acid             0.31000    0.39000    1.66000
# residual_sugar          3.00000    8.10000   65.80000
# chlorides               0.04700    0.06500    0.61100
# free_sulfur_dioxide    29.00000   41.00000  289.00000
# total_sulfur_dioxide  118.00000  156.00000  440.00000
# density                 0.99489    0.99699    1.03898
# pH                      3.21000    3.32000    4.01000
# sulphates               0.51000    0.60000    2.00000
# alcohol                10.30000   11.30000   14.90000
# quality                 6.00000    6.00000    9.00000

# %%
# verificar a existência de dados nulos
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# style                   0
# dtype: int64

# %%
# Em caso de haver dados nulos analisar melhor estratégia para a situação pontual

# %% [markdown]
# <center style="font-size:18pt; background-color:#0f79b6">
#     <br/>
#         <b style="color: #ffffff">
#             DATA PREPARATION
#         </b>
#     <br/>&nbsp;
# </center>

# %%
df['style'] = df['style'].replace('red', 0) # vinho tinto
df['style'] = df['style'].replace('white', 1) # vinho branco

# %%
# Analisar a correlação entre as variáveis da base de dados
plt.figure(figsize=(15,5))
sns.heatmap(df.corr(),annot=True);

# %%
# 1 - VERIFICAR NECESSIDADE DE APLICAR O GET DUMMIES para cada base de dados
# df_d = pd.get_dummies(df)
# df_d.sample(5)

# %% [markdown]
# # DATA VISUALIZATION

# %%
# wine ranking
plt.figure(figsize=(15,5))
df['quality'].value_counts(ascending=True).plot.barh()
plt.grid()
plt.show();

# %%
# frequência geral de pH dos vinhos
df['pH'].plot.hist();

# %%
# ANALISANDO a qualidade geral dos vinhos em relação a característica tinto e branco
# (df.loc[df['style']== 1]).hist(figsize=(15,5));
# df['quality'].hist()

# min = df['quality'].min()
# max = df['quality'].max()
# bins = np.linspace(min,max, 6)

plt.figure(figsize=(15,5))
(df['quality'].loc[df['style']== 1]).hist(rwidth=0.80, color='b', alpha=.3, density=True, label='vinho branco') # vinhos branco
(df['quality'].loc[df['style']== 0]).hist(rwidth=0.80, color='r', alpha=.3, density=True, label='vinho tinto') # vinhos tinto;
plt.legend();

# %% [markdown]
# # Análise dos outliers (df)

# %%
# Outliers data frame df
plt.figure(figsize=(15,5))
ax = sns.boxplot(data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.title('outliers dataset original')
plt.grid()
plt.show();

# %%
# LIMITE INFERIOR E SUPERIOR DO BOX PLOT DE VARIÁVEL ESPECÍFICA
var = 'total_sulfur_dioxide'
q1 = df[var].quantile(0.25)
q2 = df[var].quantile(0.5)
q3 = df[var].quantile(0.75)
amplitude = q3 - q1
limite_inferior = q1 - (1.5 * amplitude)
limite_superior = q3 + (1.5 * amplitude)
menor_valor_serie = df[var].min()
maior_valor_serie = df[var].max()
quant_dados_ALS = df.loc[df[var] > limite_superior].count()[0] # quantidade de dados acima do limite superior
quant_dados_BLI = df.loc[df[var] < limite_inferior].count()[0] # quantidade de dados abaixo do limite inferior
perc_ALS = (((df.loc[df[var] > limite_superior]).count()[0] / df[var].count())) * 100
perc_BLI = (((df.loc[df[var] < limite_inferior]).count()[0] / df[var].count())) * 100
box_splot = {
        'perc_BLI':[perc_BLI],
        'quant_dados_BLS':[quant_dados_BLI],
        'menor_valor_serie':[menor_valor_serie],
        'LI_box_splot':[limite_inferior],
        'q1':[q1],
        'q2':[q2],
        'q3':[q3],
        'LS_box_splot':[limite_superior],
        'maior_valor_serie':[maior_valor_serie],
        'quant_dados_ALS':[quant_dados_ALS],
        'perc_ALS':[perc_ALS]        
}
df_box_splot = pd.DataFrame(box_splot)
df_box_splot
# Out:
# C:\Users\geanc\AppData\Local\Temp\ipykernel_6768\505867337.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quant_dados_ALS = df.loc[df[var] > limite_superior].count()[0] # quantidade de dados acima do limite superior
# C:\Users\geanc\AppData\Local\Temp\ipykernel_6768\505867337.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quant_dados_BLI = df.loc[df[var] < limite_inferior].count()[0] # quantidade de dados abaixo do limite inferior
# C:\Users\geanc\AppData\Local\Temp\ipykernel_6768\505867337.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   perc_ALS = (((df.loc[df[var] > limite_superior]).count()[0] / df[var].count())) * 100
# C:\Users\geanc\AppData\Local\Temp\ipykernel_6768\505867337.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   perc_BLI = (((df.loc[df[var] < limite_inferior]).count()[0] / df[var].count())) * 100
#    perc_BLI  quant_dados_BLS  menor_valor_serie  LI_box_splot    q1     q2  \
# 0       0.0                0                6.0         -41.5  77.0  118.0
#
#       q3  LS_box_splot  maior_valor_serie  quant_dados_ALS  perc_ALS
# 0  156.0         274.5              440.0               10  0.153917

# %%
# Outliers var
plt.figure(figsize=(15,5))
ax = sns.boxplot(data=df[var])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.title(var)
plt.text(0.4, limite_superior, f"Quant de dados acima do limite superior: {quant_dados_ALS}", ha='right',
         va='bottom', fontsize=10, color='red')
plt.text(0.4, limite_inferior, f"Quant de dados abaixo do limite inferior: {quant_dados_BLI}", ha='right',
         va='bottom', fontsize=10, color='blue')
plt.grid()
plt.show();

# %%
# Outliers acima do limite superior boxsplot var
df.loc[df[var] > limite_superior]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1079            7.9              0.30         0.68            8.30      0.050
# 1081            7.9              0.30         0.68            8.30      0.050
# 1924            7.5              0.27         0.31            5.80      0.057
# 3016            8.6              0.55         0.35           15.55      0.057
# 3530            7.1              0.49         0.22            2.00      0.047
# 3726            9.1              0.33         0.38            1.70      0.062
# 3977            9.4              0.23         0.56           16.45      0.063
# 4253            6.9              0.40         0.22            5.95      0.081
# 4751            7.6              0.25         1.23            4.60      0.035
# 6344            6.1              0.26         0.25            2.90      0.047
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1079                 37.5                 278.0  0.99316  3.01       0.51
# 1081                 37.5                 289.0  0.99316  3.01       0.51
# 1924                131.0                 313.0  0.99460  3.18       0.59
# 3016                 35.5                 366.5  1.00010  3.04       0.63
# 3530                146.5                 307.5  0.99240  3.24       0.37
# 3726                 50.5                 344.0  0.99580  3.10       0.70
# 3977                 52.5                 282.0  1.00098  3.10       0.51
# 4253                 76.0                 303.0  0.99705  3.40       0.57
# 4751                 51.0                 294.0  0.99018  3.03       0.43
# 6344                289.0                 440.0  0.99314  3.44       0.64
#
#       alcohol  quality  style
# 1079     12.3        7      0
# 1081     12.3        7      0
# 1924     10.5        5      1
# 3016     11.0        3      1
# 3530     11.0        3      1
# 3726      9.5        5      1
# 3977      9.3        5      1
# 4253      9.4        5      1
# 4751     13.1        6      1
# 6344     10.5        3      1

# %%
# Instanciando o objeto KNN para detectar os outlers df
# Obs: uma das formas de tratar outliers mas que não é a mais adequada ou a certa, pois depende do contexto dos dados
detector = KNN()

# Treinar o detector de OUTLIERS
detector.fit(df)
# Out:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0)

# %%
# 0 -> NÃO é outlier
# 1 -> outlier
previsoes = detector.labels_
previsoes
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Fazendo uma contagem para identificar os outliers
np.unique(previsoes, return_counts = True)
# Out:
# (array([0, 1]), array([5847,  650], dtype=int64))

# %%
# Cálculo da distância realizado para identificação do outlier
confianca_previsoes = detector.decision_scores_
confianca_previsoes
# Out:
# array([2.12212299, 2.71635787, 2.18040046, ..., 2.34466423, 3.08154044,
#        2.51754346])

# %%
# Lista outliers
outliers = []
for i in range(len(previsoes)):    
    if previsoes[i] == 1:
        outliers.append(i)

# Filtrar as linhas outlier df
df_outliers = df.iloc[outliers,:]

# %%
# salvar versão df sem os outliers
df_sem_outliers = df.loc[~df.index.isin(outliers)]

# %%
# df_sem_outliers

# %%
df.shape, df_sem_outliers.shape
# Out:
# ((6497, 13), (5847, 13))

# %%
plt.figure(figsize=(15,5))
ax = sns.boxplot(data=df_sem_outliers)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.title('df_sem_outliers')
plt.grid()
plt.show();

# %%
# Análise variável após tratamento dos outliers
var = 'total_sulfur_dioxide'
plt.figure(figsize=(15,5))
ax = sns.boxplot(data=df_sem_outliers[var])
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.title(f'{var} - df_sem_outliers')
plt.text(0.4, limite_superior, f"limite superior", ha='right', va='bottom', fontsize=10, color='red')
plt.text(0.4, limite_inferior, f"limite inferior", ha='right', va='bottom', fontsize=10, color='blue')
plt.grid()
plt.show();

# %% [markdown]
# <center style="font-size:18pt; background-color:#0f79b6">
#     <br/>
#         <b style="color: #ffffff">
#             MODELING
#         </b>
#     <br/>&nbsp;
# </center>

# %%
# dividir em df MODEL para treinar e testar o modelo e df VALIDAÇÃO para fins de simulando o mundo real
df_model, df_validation = tts(df_sem_outliers, test_size=0.10)

# %%
# Divisão dos dados em X e y a partir do df_tr (corresponde a 70% da base utilizada para treinar o modelo)
X = df_model.drop('style', axis = 1)
y = df_model['style']
X.shape, y.shape
# Out:
# ((5262, 12), (5262,))

# %%
# Variável de validação final para o modelo gerado (corresponde a 30% dos dados simulando mundo real)
X_val = df_validation.drop('style', axis = 1)
y_val = df_validation['style']

# %%
df.groupby('style').size()[0], df.groupby('style').size()[1]
# Out:
# (1599, 4898)

# %%
plt.figure(figsize=(15,5))
ax = y.value_counts(ascending=True).plot(kind ='barh', color = ['red','blue'])
ax.set_xlabel('Count')
ax.set_ylabel('Value')
ax.set_title('Value Counts')
ax.bar_label(ax.containers[0], label_type='edge');

# %%
# quantidade de 0 e 1 na variável y do df
np.unique(y, return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([1381, 3881], dtype=int64))

# %%
percentual_0 = np.bincount(y)[0] / len(y) * 100
percentual_1 = np.bincount(y)[1] / len(y) * 100
percentual_0, percentual_1
# Out:
# (26.244773850247054, 73.75522614975296)

# %% [markdown]
# # Data balancing

# %%
# OBSERVALÇÃO IMPORTANTE: CONFIRMAR EM QUE MOMENTO É O MAIS ADEQUADO PARA O BALANCEAMENTO DOS DADOS!
# OBSERVALÇÃO IMPORTANTE: CONFIRMAR EM QUE MOMENTO É O MAIS ADEQUADO PARA O BALANCEAMENTO DOS DADOS!
# OBSERVALÇÃO IMPORTANTE: CONFIRMAR EM QUE MOMENTO É O MAIS ADEQUADO PARA O BALANCEAMENTO DOS DADOS!

# balancemaneto dos dados com a geração de dados aleatórios na base minoritária de y
smote_ball = SMOTE()
X_bal, y_bal = smote_ball.fit_resample(X, y)

# balancemaneto dos dados com a remoção de dados da base majoritária de y
# rus = RandomUnderSampler()
# X_bal, y_bal = rus.fit_resample(X, y)

# %%
# y_bal.value_counts()

# %%
# variável y, balanceada, utilizada para TREINAR o modelo
y_bal.value_counts(ascending=True).plot(kind = 'barh', color = ['blue', 'red']);

# %%
# Variável y, base de validação, utilizada para aplicar situações novas ao modelo já treinado e simulando vida real
y_val.value_counts(ascending=True).plot(kind = 'barh', color = ['red','blue']);

# %% [markdown]
# # Standardization

# %%
# Padronizar X_bal do X do df_tr
obj_padronizado = StandardScaler().fit(X_bal)
X_bal_padronizado = obj_padronizado.transform(X_bal)
X_bal_padronizado = pd.DataFrame(X_bal_padronizado)
X_bal_padronizado.columns = list(X_bal.columns)

# %%
X_bal_padronizado.tail()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 7757       2.687339          0.410777     0.626023       -0.720431   0.669568
# 7758      -0.158824          0.448847    -0.767462       -0.317817   0.293096
# 7759       0.995616          0.210295     1.337385       -0.068822   1.266233
# 7760       2.563012         -0.396296     1.228940       -0.554414   0.456732
# 7761       1.120866         -0.113109     0.969644        0.034667   0.607711
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density        pH  \
# 7757            -1.221569             -1.089041  0.661644 -1.137625
# 7758            -0.578376             -0.929717  0.468750  0.737910
# 7759            -1.417645             -1.400604  0.212053 -0.208256
# 7760            -1.252257             -1.319176  1.279845 -1.841392
# 7761            -1.409269             -1.407689  0.286623  0.168085
#
#       sulphates   alcohol   quality
# 7757   0.494446 -0.406204 -0.855719
# 7758  -0.418043  0.047078 -0.855719
# 7759   0.065146  1.842059  0.346687
# 7760   0.682549 -1.155481  0.346687
# 7761   0.482654  1.605525  1.549094

# %%
# df_padronizado.describe().T

# %%
# plt.figure(figsize=(15,5))
# ax = sns.boxplot(data=df_padronizado)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
# Padronizar X_val (origem no df_ts correspondente a 30% dos dados do df para teste do modelo)
obj_padronizado = StandardScaler().fit(X_val)
X_val_padronizado = obj_padronizado.transform(X_val)
X_val_padronizado = pd.DataFrame(X_val_padronizado)
X_val_padronizado.columns = list(X_val.columns)
X_val_padronizado.tail()
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 580      -0.642135         -1.079882    -0.425300       -0.819425  -0.006226
# 581      -0.881097         -0.369706    -0.289566       -0.062263  -0.624695
# 582      -0.721789          0.902692    -0.628900       -0.727648  -0.258195
# 583       1.269564          1.524096    -0.153832       -0.635871   0.932932
# 584      -0.642135         -0.132981     1.271374        1.314394  -0.235289
#
#      free_sulfur_dioxide  total_sulfur_dioxide   density        pH  sulphates  \
# 580            -0.492390              0.299876 -1.271849  0.038967  -0.621209
# 581             1.702145              0.580097 -1.441181 -0.377669  -0.752166
# 582             0.134620              0.580097 -0.584153  0.991280   0.033579
# 583            -1.495606             -1.755077  1.454745  0.812721  -0.293815
# 584             1.764846              1.813069  0.763593 -0.853825   0.426451
#
#       alcohol   quality
# 580  0.515218  1.409666
# 581  1.705637  2.569517
# 582 -0.079991  0.249814
# 583 -1.185380 -0.910037
# 584 -0.930290 -0.910037

# %% [markdown]
# # Normalization

# %%
# obj_normalizado = MinMaxScaler().fit(X_bal)
# df_normalizado = obj_normalizado.transform(X_bal)
# df_normalizado = pd.DataFrame(df_normalizado)
# df_normalizado.columns = list(X_bal.columns)
# df_normalizado.head()

# %%
# df_normalizado.describe().T

# %%
# plt.figure(figsize=(15,5))
# ax = sns.boxplot(data=df_normalizado)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45);

# %%
# Analisar os outliers
plt.figure(figsize=(15,5))
ax = sns.boxplot(data=X_bal_padronizado)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show();

# %% [markdown]
# # VALIDAÇÃO HOLDOUT
# # Separar df_model - balanceado e padronizado - em X_tr, X_ts, y_tr, y_ts

# %%
# Separar df_model - balanceado e padronizado - em X_tr, X_ts, y_tr, y_ts
PREDICTOR = X_bal_padronizado
TARGET = y_bal
X_tr, X_ts, y_tr, y_ts = tts(PREDICTOR,TARGET, test_size= 0.3)

# %%
X_tr.shape, X_ts.shape, y_tr.shape, y_ts.shape, y_tr.value_counts()[0], y_tr.value_counts()[1]
# Out:
# ((5433, 12), (2329, 12), (5433,), (2329,), 2717, 2716)

# %% [markdown]
# <a name="etc"></a>
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Extra Trees Classifier
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# <div style="overflow: auto;">
#     <div style="float: left;">
#         <a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html">
#             Consultar documentação "ExtraTreesClassifier"
#         </a>
#     </div>
#     <div style="float: right;">
#         <a href="#índice">
#             Índice deste notebook
#         </a>
#     </div>
# </div>

# %%
# Treinar o modelo
# etc = ExtraTreesClassifier(n_estimators=500, max_depth=10, n_jobs=-1)
# etc.fit(X_tr, y_tr)
# etc_y_pred = etc.predict(X_ts)

# %%
# Treinar o modelo
params = {    
    'n_estimators': np.arange(250, 750, 250),
    'max_depth': np.arange(5, 15, 5),
    'n_jobs': np.array([-1])
}
etc = GridSearchCV(
    ExtraTreesClassifier(),
    params,                                    
    cv=10,                                     
    scoring='roc_auc',
#     verbose=5,
)
etc.fit(X_tr, y_tr)
# Out:
# GridSearchCV(cv=10, estimator=ExtraTreesClassifier(),
#              param_grid={'max_depth': array([ 5, 10]),
#                          'n_estimators': array([250, 500]),
#                          'n_jobs': array([-1])},
#              scoring='roc_auc')

# %%
etc.best_params_, etc.best_score_, etc.best_estimator_, etc.best_index_
# Out:
# ({'max_depth': 10, 'n_estimators': 250, 'n_jobs': -1},
#  0.9991517364081511,
#  ExtraTreesClassifier(max_depth=10, n_estimators=250, n_jobs=-1),
#  2)

# %%
etc_y_pred = etc.predict(X_ts)

# %%
# PROPENSÃO respectiva, nas colunas, da variável resposta ser 0 e 1
etc.predict_proba(X_ts)
# Out:
# array([[0.02362468, 0.97637532],
#        [0.00714061, 0.99285939],
#        [0.01892122, 0.98107878],
#        ...,
#        [0.94364747, 0.05635253],
#        [0.02907057, 0.97092943],
#        [0.01392614, 0.98607386]])

# %%
# Data frame PROPENSÃO respectiva, nas colunas, da variável resposta ser 0 e 1
pd.DataFrame(etc.predict_proba(X_ts), columns=['Propensão 0', 'Propensão 1']).head()
# Out:
#    Propensão 0  Propensão 1
# 0     0.023625     0.976375
# 1     0.007141     0.992859
# 2     0.018921     0.981079
# 3     0.920768     0.079232
# 4     0.979236     0.020764

# %% [markdown]
# # EVALUATION

# %%
# Max e Min
etc_y_pred.min(), etc_y_pred.max()
# Out:
# (0, 1)

# %%
# Curva ROC
roc_auc_score(y_ts, etc_y_pred)
# Out:
# 0.9926990693627126

# %%
# Calculando a curva ROC
# A curva ROC é um gráfico que representa a taxa de verdadeiros positivos (TPR)
# em função da taxa de falsos positivos (FPR) para diferentes valores de limiar de classificação.

fpr, tpr, thresholds = roc_curve(y_ts, etc_y_pred)

# Plotando a curva ROC
color = 'orange'
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color=color, label='Curva ROC')
plt.fill_between(fpr, tpr, color=color, alpha=.25)
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
plt.xlabel('Taxa de Falsos Positivos FPR')
plt.ylabel('Taxa de Verdadeiros Positivos TPR')
plt.title('Curva ROC')
plt.legend()
plt.show()

# Calculando a área sob a curva (AUC)
# A área sob a curva ROC (AUC-ROC) é uma métrica resumida que quantifica o desempenho global do modelo.
# Um valor de AUC-ROC próximo a 1 indica um bom modelo, enquanto um valor próximo a 0,5 indica um desempenho aleatório.
roc_auc = auc(fpr, tpr)
print(f'AUC: {roc_auc:.2f}')
# Out:
# AUC: 0.99

# %%
# SCORE
etc_acuracia = etc.score(X_ts, y_ts)
print("score AUTO:", etc_acuracia)
# Out:
# score AUTO: 0.9991770275651519

# %%
# ACURÁCIA
etc_acuracia = accuracy_score(y_ts, etc_y_pred)
print("accuracy_score AUTO:", etc_acuracia)
# Out:
# accuracy_score AUTO: 0.9927007299270073

# %%
# média dos acertos do modelo em relação aos valores corretos da base de dados
np.mean(y_ts == etc_y_pred)
# Out:
# 0.9927007299270073

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
etc_recall = recall_score(y_ts, etc_y_pred)
print("etc_recall:", etc_recall)
# Out:
# etc_recall: 0.9965665236051502

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
etc_precision = precision_score(y_ts, etc_y_pred)
print("precision_score:", etc_precision)
# Out:
# precision_score: 0.9889267461669506

# %%
# MATRIZ CONFUSÃO
etc_confusion_matrix = confusion_matrix(y_ts, etc_y_pred)
etc_confusion_matrix
# Out:
# array([[1151,   13],
#        [   4, 1161]], dtype=int64)

# %% [markdown]
# |                     |  PRED = 0          |           PRED = 1   |
# |-                    |--------------------|----------------------|
# | *REAL = 0*          |      VN            |             FP       |
# | *REAL = 1*          |      FN            |             VP       |

# %%
# CÁLCULO MANUAL DA ACURÁCIA
# com base nos valores da matriz confusão
etc_acuracia_manual = (etc_confusion_matrix[0][0] + etc_confusion_matrix[1][1])/(etc_confusion_matrix[0][0] + etc_confusion_matrix[0][1] + etc_confusion_matrix[1][0] + etc_confusion_matrix[1][1])
print(f'Acurácia MANUAL:, {etc_acuracia_manual}')
# Out:
# Acurácia MANUAL:, 0.9927007299270073

# %%
# print(classification_report(y_ts, etc_y_pred))

# %%
etc_f1_score = f1_score(y_ts, etc_y_pred)
etc_f1_score
# Out:
# 0.9927319367250962

# %%
# X_ts[400:410].T
X_val_padronizado[400:410].T
# Out:
#                            400       401       402       403       404  \
# fixed_acidity        -0.084556  0.473023  1.827143 -0.164210  0.473023
# volatile_acidity      0.222107  1.287370  0.695557 -1.139063  0.932283
# citric_acid          -0.153832 -0.832501  1.203507 -0.221699 -1.307570
# residual_sugar        1.979778 -0.658815  0.304845  2.232166 -0.727648
# chlorides            -0.372726  0.543525  0.154118 -0.143663  2.765434
# free_sulfur_dioxide   0.071919 -0.868596 -1.495606  0.009218 -1.432905
# total_sulfur_dioxide  0.524053 -0.073752 -1.717714  0.748230 -1.642988
# density               0.006782  0.556247  1.454745  1.150638  0.487132
# pH                   -1.210942  0.634163 -0.080072 -1.568059  0.336565
# sulphates             2.783687  0.033579  1.277675 -0.948603  2.194378
# alcohol               1.365517 -0.845260  0.430188 -1.270410 -0.590170
# quality               0.249814 -0.910037  0.249814  1.409666  0.249814
#
#                            405       406       407       408       409
# fixed_acidity        -0.004902 -0.721789  0.234061 -0.243864 -0.801443
# volatile_acidity      0.340470 -0.310525  1.405733 -0.665613 -0.251343
# citric_acid          -0.493166 -0.221699 -1.171836 -0.493166 -0.968235
# residual_sugar        0.809620 -0.062263 -0.635871  2.117444 -0.498205
# chlorides            -0.052038  0.039587  0.451900 -0.097851 -0.395633
# free_sulfur_dioxide   1.012434 -0.053483 -0.116184 -0.617792 -0.304287
# total_sulfur_dioxide  0.785592 -0.522105 -0.914414 -0.279247  0.299876
# density               0.576982 -1.461916  0.590805  1.247399 -0.238577
# pH                   -0.139591  0.098487  0.336565 -0.318150 -1.270462
# sulphates            -0.097379  0.164536  0.360973 -0.228336 -0.490251
# alcohol              -1.100350  1.875696 -0.590170 -0.760230 -1.270410
# quality              -0.910037  2.569517 -0.910037 -0.910037 -0.910037

# %% [markdown]
# # Testar o modelo com dados da base df_validation

# %%
# segmento da base y_ts que serve para validar o modelo
# selection_y_ts = list(y_ts[400:410].values)
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print (validation, end=' ')

# %%
len(validation)
# Out:
# 585

# %%
# aplicação do modelo para predizer resultados com base na base treino e modelo gerado
prediction = list(etc.predict(X_val_padronizado[start:end]))
# prediction = list(etc.predict(X_ts[400:410]))
# print(prediction, end=' ')

# %%
len(prediction)
# Out:
# 585

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    etc_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    display(dfp.prediction.value_counts())
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# 13 tipo(s) de vinho(s) NÃO previstos corretamente!
# prediction
# 0    13
# Name: count, dtype: int64
#     seq  validation  prediction
# 8   320           1           0
# 9   333           1           0
# 10  425           1           0
# 11  535           1           0
# 12  547           1           0

# %%
# MATRIZ CONFUSÃO - df Validação
etc_y_pred_val = etc.predict(X_val_padronizado)
confusion_matrix(y_val, etc_y_pred_val)
# Out:
# array([[158,   0],
#        [ 13, 414]], dtype=int64)

# %% [markdown]
# # VISUAL

# %%
# PROPENSÃO (NÃO É probabilidade)
pred = etc.predict_proba(X_ts)[:,1]

# %%
pred.min(), pred.max()
# Out:
# (0.0016719093658980947, 0.9985740161453632)

# %%
plt.figure(figsize=(15,5))
plt.hist(pred[y_ts==0], bins=np.linspace(0,1,10), density=True, color='r', alpha=.3, rwidth=.8, label='vinho tinto')
plt.hist(pred[y_ts==1], bins=np.linspace(0,1,10), density=True, color='b', alpha=.3, rwidth=.8, label='vinho branco')

plt.xlim(0, 1)
plt.ylim(0, 10)

plt.xticks(np.arange(0,1.1,0.1), fontsize=15)
plt.yticks([])
plt.legend(fontsize=15)
plt.grid();

# %% [markdown]
# # PERSISTENCE

# %%
# Salvar modelo em arquivo
# current_date = datetime.today().strftime('%Y-%m-%d')
# name = "wine_classifier_etc_"
# file_name = f'{name}{current_date}.joblib'
# file_path = fr'C:\Users\geanc\OneDrive\Documentos\GitHub\machine-learning\{file_name}'
# joblib.dump(etc, file_path)

# %%
# Carregar Modelo Salvo
# model = joblib.load(r'C:\Users\geanc\OneDrive\Documentos\GitHub\machine-learning\wine_classifier_etc.joblib')
# prediction_persistence = model.predict(X_ts[400:410])
# print(list(prediction_persistence))

# %% [markdown]
# # DEPLOYMENT

# %%
# Criar tela no Streamlit para aplciar o modelo em situação de produção
# receber arquivo com dados em upload e retornar resultado na tela com tipo de vinho

# %% [markdown]
# # INSIGHTS

# %%
# 1 - verificar dados outliers
# 2 - a base pode conter a nacionalidade e outras características que podem ajudar na classificação

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             KNeighbors Classifier
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# [KNeighbors Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %% [markdown]
# # VALIDAÇÃO CRUZADA

# %%
# Treinar o modelo
params = {
    'n_neighbors': np.arange(3, 11, 2)
}
neigh = GridSearchCV(
    KNeighborsClassifier(),
    params,                                    
    cv=10,                                     
    scoring='roc_auc',
#     verbose=5,
)

# %%
print(neigh)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': array([3, 5, 7, 9])},
#              scoring='roc_auc')

# %%
neigh.fit(X_tr, y_tr)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': array([3, 5, 7, 9])},
#              scoring='roc_auc')

# %%
neigh.best_params_, neigh.best_score_, neigh.best_estimator_, neigh.best_index_
# Out:
# ({'n_neighbors': 9},
#  0.9983262163395855,
#  KNeighborsClassifier(n_neighbors=9),
#  3)

# %%
neigh_y_pred = neigh.predict(X_ts)

# %%
# MATRIZ CONFUSÃO
neigh_confusion_matrix = confusion_matrix(y_ts, neigh_y_pred)
neigh_confusion_matrix
# Out:
# array([[1154,   10],
#        [  18, 1147]], dtype=int64)

# %%
# ACURÁCIA
neigh_acuracia = accuracy_score(y_ts, neigh_y_pred)
print("neigh_acuracia:", neigh_acuracia)
# Out:
# neigh_acuracia: 0.9879776728209532

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
neigh_recall = recall_score(y_ts, neigh_y_pred)
print("neigh_recall:", neigh_recall)
# Out:
# neigh_recall: 0.984549356223176

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
neigh_precision = precision_score(y_ts, neigh_y_pred)
print("precision_score:", neigh_precision)
# Out:
# precision_score: 0.9913569576490925

# %%
print(classification_report(y_ts, neigh_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1164
#            1       0.99      0.98      0.99      1165
#
#     accuracy                           0.99      2329
#    macro avg       0.99      0.99      0.99      2329
# weighted avg       0.99      0.99      0.99      2329

# %%
neigh_f1_score = f1_score(y_ts, neigh_y_pred)
neigh_f1_score
# Out:
# 0.987941429801895

# %% [markdown]
# # Validação K-FOLD

# %%
# validacao = KFold(n_splits = 10, shuffle = True)
validacao = RepeatedStratifiedKFold(n_splits = 10, n_repeats = 3)

# %%
reglog = cross_validate(neigh, X_bal_padronizado, y_bal, cv = validacao, scoring = ['accuracy', 'recall', 'precision'])

# %%
print('     Acurácia:', round(reglog['test_accuracy'].mean(), 4))
print('Sensibilidade:', round(reglog['test_recall'].mean(), 4))
print('     Precisão:', round(reglog['test_precision'].mean(), 4))
# Out:
#      Acurácia: 0.9918
# Sensibilidade: 0.9919
#      Precisão: 0.9918

# %% [markdown]
# # Testar o modelo com dados da base df_validation

# %%
# segmento da base y_ts que serve para validar o modelo
# selection_y_ts = list(y_ts[400:410].values)
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print (validation, end=' ')

# %%
# aplicação do modelo para predizer resultados com base na base treino e modelo gerado
prediction = list(neigh.predict(X_val_padronizado[start:end]))
# prediction = list(etc.predict(X_ts[400:410]))
# print(prediction, end=' ')

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    neigh_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO identificados corretamente!')
    display(dfp.prediction.value_counts())
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# 23 tipo(s) de vinho(s) NÃO identificados corretamente!
# prediction
# 0    23
# Name: count, dtype: int64
#     seq  validation  prediction
# 18  425           1           0
# 19  516           1           0
# 20  564           1           0
# 21  571           1           0
# 22  582           1           0

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Decision Tree Classifier
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# [Decision Tree Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %% [markdown]
# # VALIDAÇÃO CRUZADA

# %%
params = {
    'max_leaf_nodes': np.power(2, (np.arange(1, 12, 1))),
    'criterion': ['gini','entropy']
}
dtc = GridSearchCV(
    DecisionTreeClassifier(),
    params,                                    
    cv=10,                                     
    scoring='roc_auc',
    verbose=5,
)

# %%
print(dtc)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_leaf_nodes': array([   2,    4,    8,   16,   32,   64,  128,  256,  512, 1024, 2048],
#       dtype=int32)},
#              scoring='roc_auc', verbose=5)

# %%
# Treinar o modelo
# dtc = DecisionTreeClassifier()
# dtc.fit(X_tr, y_tr)
dtc.fit(X_tr, y_tr)
# Out:
# Fitting 10 folds for each of 22 candidates, totalling 220 fits
# [CV 1/10] END .criterion=gini, max_leaf_nodes=2;, score=0.936 total time=   0.0s
# [CV 2/10] END .criterion=gini, max_leaf_nodes=2;, score=0.934 total time=   0.0s
# [CV 3/10] END .criterion=gini, max_leaf_nodes=2;, score=0.938 total time=   0.0s
# [CV 4/10] END .criterion=gini, max_leaf_nodes=2;, score=0.930 total time=   0.0s
# [CV 5/10] END .criterion=gini, max_leaf_nodes=2;, score=0.912 total time=   0.0s
# [CV 6/10] END .criterion=gini, max_leaf_nodes=2;, score=0.936 total time=   0.0s
# [CV 7/10] END .criterion=gini, max_leaf_nodes=2;, score=0.924 total time=   0.0s
# [CV 8/10] END .criterion=gini, max_leaf_nodes=2;, score=0.915 total time=   0.0s
# [CV 9/10] END .criterion=gini, max_leaf_nodes=2;, score=0.908 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=2;, score=0.913 total time=   0.0s
# [CV 1/10] END .criterion=gini, max_leaf_nodes=4;, score=0.973 total time=   0.0s
# [CV 2/10] END .criterion=gini, max_leaf_nodes=4;, score=0.963 total time=   0.0s
# [CV 3/10] END .criterion=gini, max_leaf_nodes=4;, score=0.969 total time=   0.0s
# [CV 4/10] END .criterion=gini, max_leaf_nodes=4;, score=0.972 total time=   0.0s
# [CV 5/10] END .criterion=gini, max_leaf_nodes=4;, score=0.968 total time=   0.0s
# [CV 6/10] END .criterion=gini, max_leaf_nodes=4;, score=0.971 total time=   0.0s
# [CV 7/10] END .criterion=gini, max_leaf_nodes=4;, score=0.959 total time=   0.0s
# [CV 8/10] END .criterion=gini, max_leaf_nodes=4;, score=0.954 total time=   0.0s
# [CV 9/10] END .criterion=gini, max_leaf_nodes=4;, score=0.966 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=4;, score=0.970 total time=   0.0s
# [CV 1/10] END .criterion=gini, max_leaf_nodes=8;, score=0.992 total time=   0.0s
# [CV 2/10] END .criterion=gini, max_leaf_nodes=8;, score=0.986 total time=   0.0s
# [CV 3/10] END .criterion=gini, max_leaf_nodes=8;, score=0.979 total time=   0.0s
# [CV 4/10] END .criterion=gini, max_leaf_nodes=8;, score=0.988 total time=   0.0s
# [CV 5/10] END .criterion=gini, max_leaf_nodes=8;, score=0.983 total time=   0.0s
# [CV 6/10] END .criterion=gini, max_leaf_nodes=8;, score=0.980 total time=   0.0s
# [CV 7/10] END .criterion=gini, max_leaf_nodes=8;, score=0.974 total time=   0.0s
# [CV 8/10] END .criterion=gini, max_leaf_nodes=8;, score=0.968 total time=   0.0s
# [CV 9/10] END .criterion=gini, max_leaf_nodes=8;, score=0.974 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=8;, score=0.982 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=16;, score=0.985 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=16;, score=0.983 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=16;, score=0.979 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=16;, score=0.991 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=16;, score=0.983 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=16;, score=0.990 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=16;, score=0.971 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=16;, score=0.984 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=16;, score=0.974 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=16;, score=0.980 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=32;, score=0.982 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=32;, score=0.982 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=32;, score=0.978 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=32;, score=0.992 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=32;, score=0.973 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=32;, score=0.983 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=32;, score=0.982 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=32;, score=0.980 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=32;, score=0.980 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=32;, score=0.976 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=64;, score=0.982 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=64;, score=0.973 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=64;, score=0.958 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=64;, score=0.983 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=64;, score=0.978 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=64;, score=0.985 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=64;, score=0.981 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=64;, score=0.983 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=64;, score=0.975 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=64;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=128;, score=0.982 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=128;, score=0.983 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=128;, score=0.976 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=128;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=128;, score=0.974 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=128;, score=0.985 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=128;, score=0.985 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=128;, score=0.989 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=128;, score=0.985 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=128;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=256;, score=0.982 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=256;, score=0.985 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=256;, score=0.978 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=256;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=256;, score=0.980 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=256;, score=0.987 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=256;, score=0.989 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=256;, score=0.985 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=256;, score=0.987 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=256;, score=0.982 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=512;, score=0.980 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=512;, score=0.982 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=512;, score=0.980 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=512;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=512;, score=0.978 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=512;, score=0.983 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=512;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=512;, score=0.983 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=512;, score=0.982 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=512;, score=0.982 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=1024;, score=0.985 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=1024;, score=0.985 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=1024;, score=0.976 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=1024;, score=0.987 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=1024;, score=0.976 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=1024;, score=0.983 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=1024;, score=0.985 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=1024;, score=0.983 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=1024;, score=0.983 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=1024;, score=0.982 total time=   0.0s
# [CV 1/10] END criterion=gini, max_leaf_nodes=2048;, score=0.982 total time=   0.0s
# [CV 2/10] END criterion=gini, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 3/10] END criterion=gini, max_leaf_nodes=2048;, score=0.980 total time=   0.0s
# [CV 4/10] END criterion=gini, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 5/10] END criterion=gini, max_leaf_nodes=2048;, score=0.976 total time=   0.0s
# [CV 6/10] END criterion=gini, max_leaf_nodes=2048;, score=0.983 total time=   0.0s
# [CV 7/10] END criterion=gini, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 8/10] END criterion=gini, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 9/10] END criterion=gini, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 10/10] END criterion=gini, max_leaf_nodes=2048;, score=0.983 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=2;, score=0.936 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=2;, score=0.934 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=2;, score=0.938 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=2;, score=0.930 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=2;, score=0.912 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=2;, score=0.936 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=2;, score=0.924 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=2;, score=0.915 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=2;, score=0.913 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=2;, score=0.917 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=4;, score=0.981 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=4;, score=0.981 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=4;, score=0.981 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=4;, score=0.992 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=4;, score=0.977 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=4;, score=0.977 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=4;, score=0.973 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=4;, score=0.974 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=4;, score=0.979 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=4;, score=0.982 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=8;, score=0.986 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=8;, score=0.990 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=8;, score=0.988 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=8;, score=0.997 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=8;, score=0.990 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=8;, score=0.992 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=8;, score=0.992 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=8;, score=0.993 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=8;, score=0.993 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=8;, score=0.993 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=16;, score=0.993 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=16;, score=0.982 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=16;, score=0.990 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=16;, score=0.997 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=16;, score=0.993 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=16;, score=0.997 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=16;, score=0.993 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=16;, score=0.996 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=16;, score=0.988 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=16;, score=0.988 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=32;, score=0.987 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=32;, score=0.982 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=32;, score=0.991 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=32;, score=0.999 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=32;, score=0.965 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=32;, score=1.000 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=32;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=32;, score=0.991 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=32;, score=0.994 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=32;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=64;, score=0.987 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=64;, score=0.985 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=64;, score=0.991 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=64;, score=0.987 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=64;, score=0.978 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=64;, score=0.994 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=64;, score=0.985 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=64;, score=0.991 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=64;, score=0.987 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=64;, score=0.987 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=128;, score=0.983 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=128;, score=0.987 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=128;, score=0.991 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=128;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=128;, score=0.982 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=128;, score=0.989 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=128;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=128;, score=0.991 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=128;, score=0.991 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=128;, score=0.983 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=256;, score=0.985 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=256;, score=0.987 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=256;, score=0.991 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=256;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=256;, score=0.983 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=256;, score=0.991 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=256;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=256;, score=0.989 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=256;, score=0.993 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=256;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=512;, score=0.985 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=512;, score=0.987 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=512;, score=0.989 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=512;, score=0.987 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=512;, score=0.980 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=512;, score=0.989 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=512;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=512;, score=0.991 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=512;, score=0.989 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=512;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.985 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.987 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.989 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.987 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.978 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.993 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.991 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.989 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=1024;, score=0.985 total time=   0.0s
# [CV 1/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.983 total time=   0.0s
# [CV 2/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# [CV 3/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.991 total time=   0.0s
# [CV 4/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.989 total time=   0.0s
# [CV 5/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.980 total time=   0.0s
# [CV 6/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.993 total time=   0.0s
# [CV 7/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.983 total time=   0.0s
# [CV 8/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.989 total time=   0.0s
# [CV 9/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.983 total time=   0.0s
# [CV 10/10] END criterion=entropy, max_leaf_nodes=2048;, score=0.985 total time=   0.0s
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_leaf_nodes': array([   2,    4,    8,   16,   32,   64,  128,  256,  512, 1024, 2048],
#       dtype=int32)},
#              scoring='roc_auc', verbose=5)

# %%
dtc.best_params_, dtc.best_score_, dtc.best_estimator_
# Out:
# ({'criterion': 'entropy', 'max_leaf_nodes': 16},
#  0.9915951933159578,
#  DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=16))

# %%
dtc_y_predct_proba = dtc.predict_proba(X_ts)[:,1]

# %%
dtc_y_predct_proba
# Out:
# array([9.94442069e-01, 9.94442069e-01, 9.94442069e-01, ...,
#        8.77963126e-04, 9.94442069e-01, 9.94442069e-01])

# %%
# dtc_y_pred = dtc.predict(X_ts)
dtc_y_pred = dtc.predict(X_ts)
dtc_y_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
# tree = DecisionTreeClassifier(max_depth = 3, min_samples_split = 150)
# tree.fit(X, y)
# plt.figure(figsize = (15, 5))
# plot_tree(tree, filled=True, proportion = False, impurity = False, feature_names=list(X_tr.columns))
# plt.show();

plt.figure(figsize = (15, 5))
plot_tree(dtc.best_estimator_, max_depth = 3, filled=True,
          proportion = False, impurity = False, feature_names=list(X_tr.columns))
plt.show();

# %%
# ROC score
roc_auc_score(y_ts, dtc_y_pred)
# Out:
# 0.9832525846938925

# %%
# MATRIZ CONFUSÃO
dtc_confusion_matrix = confusion_matrix(y_ts, dtc_y_pred)
dtc_confusion_matrix
# Out:
# array([[1139,   25],
#        [  14, 1151]], dtype=int64)

# %%
# ACURÁCIA
dtc_acuracia = accuracy_score(y_ts, dtc_y_pred)
print("Acurácia:", dtc_acuracia)
# Out:
# Acurácia: 0.9832546157148991

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
dtc_recall = recall_score(y_ts, dtc_y_pred)
print("dtc_recall:", dtc_recall)
# Out:
# dtc_recall: 0.9879828326180258

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
dtc_precision = precision_score(y_ts, dtc_y_pred)
print("precision_score:", dtc_precision)
# Out:
# precision_score: 0.9787414965986394

# %%
print(classification_report(y_ts, dtc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      1164
#            1       0.98      0.99      0.98      1165
#
#     accuracy                           0.98      2329
#    macro avg       0.98      0.98      0.98      2329
# weighted avg       0.98      0.98      0.98      2329

# %%
dtc_f1_score = f1_score(y_ts, dtc_y_pred)
dtc_f1_score
# Out:
# 0.9833404527979496

# %% [markdown]
# # Testar o modelo com dados da base df_validation

# %%
# Simular dados do mundo real
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print(validation)

# %%
prediction = list(dtc.predict(X_val_padronizado[start:end]))
# print(prediction)

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    dtc_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# ---
# 62 tipo(s) de vinho(s) NÃO previstos corretamente!
# ---
# prediction
# 0    61
# 1     1
# Name: count, dtype: int64
# ---
#     seq  validation  prediction
# 57  547           1           0
# 58  568           1           0
# 59  571           1           0
# 60  572           1           0
# 61  573           1           0

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Logistic Regression
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# [Logistic Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
# Treinar o modelo
lr = LogisticRegression(max_iter =1500)
lr.fit(X_tr, y_tr)
# Out:
# LogisticRegression(max_iter=1500)

# %%
# Nos modelos de Classificação com 'Probabilidade' a interpretação corretar é propensão
# Nesse exemplo impresso, a primeira coluna reflete valores com propensão a "0" enquanto que an segunda
# coluna são apresentados valores com propensão a "1"
lr.predict_proba(X_ts).round(4).tolist()[:5]
# Out:
# [[0.0025, 0.9975],
#  [0.0013, 0.9987],
#  [0.0015, 0.9985],
#  [0.9552, 0.0448],
#  [0.9996, 0.0004]]

# %%
lr_y_pred = lr.predict(X_ts)

# %%
# Valores finais de predição do modelo "lr"
lr_y_pred.tolist()[:5]
# Out:
# [1, 1, 1, 0, 0]

# %%
# MATRIZ CONFUSÃO
lr_confusion_matrix = confusion_matrix(y_ts, lr_y_pred)
lr_confusion_matrix
# Out:
# array([[1151,   13],
#        [   2, 1163]], dtype=int64)

# %%
# ACURÁCIA
lr_acuracia = accuracy_score(y_ts, lr_y_pred)
print("Acurácia:", lr_acuracia)
# Out:
# Acurácia: 0.9935594675826535

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
lr_recall = recall_score(y_ts, lr_y_pred)
print("lr_recall:", lr_recall)
# Out:
# lr_recall: 0.9982832618025751

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
lr_precision = precision_score(y_ts, lr_y_pred)
print("precision_score:", lr_precision)
# Out:
# precision_score: 0.9889455782312925

# %%
print(classification_report(y_ts, lr_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1164
#            1       0.99      1.00      0.99      1165
#
#     accuracy                           0.99      2329
#    macro avg       0.99      0.99      0.99      2329
# weighted avg       0.99      0.99      0.99      2329

# %%
lr_f1_score = f1_score(y_ts, lr_y_pred)
lr_f1_score
# Out:
# 0.9935924818453652

# %%
prediction = list(lr.predict(X_ts[400:410]))
print(prediction)
# Out:
# [1, 1, 0, 0, 0, 1, 0, 1, 0, 1]

# %%
# Simular dados do mundo real
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print(validation)

# %%
prediction = list(lr.predict(X_val_padronizado[start:end]))
# print(prediction)

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    lr_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# ---
# 24 tipo(s) de vinho(s) NÃO previstos corretamente!
# ---
# prediction
# 0    24
# Name: count, dtype: int64
# ---
#     seq  validation  prediction
# 19  393           1           0
# 20  425           1           0
# 21  427           1           0
# 22  462           1           0
# 23  516           1           0

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Random Forest Classifier
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# [Random Forest Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %% [markdown]
# [sklearn.model_selection.GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV)

# %%
# Treinar o modelo
params = {
    'max_features' : np.arange(3, 6, 3),
    'n_estimators': np.arange(200, 400, 200),
    'max_depth': np.arange(2, 10, 2),
    'min_samples_split' : np.arange(50, 100, 50),
    'n_jobs': np.array([-1])
}
rfc = GridSearchCV(
    RandomForestClassifier(),
    params,                                    
    cv=validacao,                                     
    scoring='roc_auc',
#     verbose=5,
)
rfc.fit(X_tr, y_tr)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=None),
#              estimator=RandomForestClassifier(),
#              param_grid={'max_depth': array([2, 4, 6, 8]),
#                          'max_features': array([3]),
#                          'min_samples_split': array([50]),
#                          'n_estimators': array([200]), 'n_jobs': array([-1])},
#              scoring='roc_auc')

# %%
rfc_y_pred = rfc.predict(X_ts)

# %%
# MATRIZ CONFUSÃO
rfc_confusion_matrix = confusion_matrix(y_ts, rfc_y_pred)
rfc_confusion_matrix
# Out:
# array([[1148,   16],
#        [   5, 1160]], dtype=int64)

# %%
# ACURÁCIA
rfc_acuracia = accuracy_score(y_ts, rfc_y_pred)
print("Acurácia:", rfc_acuracia)
# Out:
# Acurácia: 0.9909832546157149

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
rfc_recall = recall_score(y_ts, rfc_y_pred)
print("rfc_recall:", rfc_recall)
# Out:
# rfc_recall: 0.9957081545064378

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
rfc_precision = precision_score(y_ts, rfc_y_pred)
print("precision_score:", rfc_precision)
# Out:
# precision_score: 0.9863945578231292

# %%
print(classification_report(y_ts, rfc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1164
#            1       0.99      1.00      0.99      1165
#
#     accuracy                           0.99      2329
#    macro avg       0.99      0.99      0.99      2329
# weighted avg       0.99      0.99      0.99      2329

# %%
rfc_f1_score = f1_score(y_ts, lr_y_pred)
rfc_f1_score
# Out:
# 0.9935924818453652

# %%
# Simular dados do mundo real
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print(validation)

# %%
prediction = list(rfc.predict(X_val_padronizado[start:end]))
# print(prediction)

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    rfc_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# ---
# 13 tipo(s) de vinho(s) NÃO previstos corretamente!
# ---
# prediction
# 0    13
# Name: count, dtype: int64
# ---
#     seq  validation  prediction
# 8   463           1           0
# 9   484           1           0
# 10  532           1           0
# 11  535           1           0
# 12  572           1           0

# %% [markdown]
# <a name="rna"></a>
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Multi-layer Perceptron (MLP)
#         </b>
#     <br/>&nbsp;
# </center>

# %% [markdown]
# <div style="overflow: auto;">
#     <div style="float: left;">
#         <a href="https://scikit-learn.org/stable/modules/neural_networks_supervised.html#classification">
#             Consultar documentação "Multi-layer Perceptron (MLP)"
#         </a>
#     </div>
#     <div style="float: right;">
#         <a href="#índice">
#             Índice deste notebook
#         </a>
#     </div>
# </div>

# %%
params = {
    'hidden_layer_sizes': [(100,), (70,100), (100,70), (100,70,30) ],
    'learning_rate_init': np.logspace(-5,-1,10,base=10),
    'alpha': np.logspace(-7,-3,10,base=10),
}
mlpc = GridSearchCV(
    MLPClassifier(
        activation='relu',
        solver='adam',
        batch_size=256,        
        early_stopping=True,
    ),
    params,
    cv=3,
    scoring='roc_auc',
    verbose=10,
    n_jobs=3,
)
mlpc.fit(X_tr,y_tr)
# Out:
# Fitting 3 folds for each of 400 candidates, totalling 1200 fits
# GridSearchCV(cv=3, estimator=MLPClassifier(batch_size=256, early_stopping=True),
#              n_jobs=3,
#              param_grid={'alpha': array([1.00000000e-07, 2.78255940e-07, 7.74263683e-07, 2.15443469e-06,
#        5.99484250e-06, 1.66810054e-05, 4.64158883e-05, 1.29154967e-04,
#        3.59381366e-04, 1.00000000e-03]),
#                          'hidden_layer_sizes': [(100,), (70, 100), (100, 70),
#                                                 (100, 70, 30)],
#                          'learning_rate_init': array([1.00000000e-05, 2.78255940e-05, 7.74263683e-05, 2.15443469e-04,
#        5.99484250e-04, 1.66810054e-03, 4.64158883e-03, 1.29154967e-02,
#        3.59381366e-02, 1.00000000e-01])},
#              scoring='roc_auc', verbose=10)

# %%
mlpc_y_pred = mlpc.predict(X_ts)
mlpc_y_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
# MATRIZ CONFUSÃO
mlpc_confusion_matrix = confusion_matrix(y_ts, mlpc_y_pred)
mlpc_confusion_matrix
# Out:
# array([[1154,   10],
#        [   3, 1162]], dtype=int64)

# %%
# ACURÁCIA
mlpc_acuracia = accuracy_score(y_ts, mlpc_y_pred)
print("Acurácia:", mlpc_acuracia)
# Out:
# Acurácia: 0.9944182052382997

# %%
# RECALL (SENSIBILIDADE)
# A revocação (sensibilidade ou recall) é uma métrica que indica, das amostras positivas existentes,
# quantas o modelo conseguiu classificar corretamente.
mlpc_recall = recall_score(y_ts, mlpc_y_pred)
print("mlpc_recall:", mlpc_recall)
# Out:
# mlpc_recall: 0.9974248927038627

# %%
# PRECISION
# A precisão é uma métrica que indica, das classificações positivas do modelo, quantas foram acertadas
mlpc_precision = precision_score(y_ts, mlpc_y_pred)
print("precision_score:", mlpc_precision)
# Out:
# precision_score: 0.9914675767918089

# %%
mlpc_f1_score = f1_score(y_ts, mlpc_y_pred)
mlpc_f1_score
# Out:
# 0.9944373127941806

# %%
etc_f1_score > mlpc_f1_score
# Out:
# False

# %%
mlpc.best_params_
# Out:
# {'alpha': 0.00012915496650148828,
#  'hidden_layer_sizes': (100, 70),
#  'learning_rate_init': 0.03593813663804626}

# %%
roc_auc_score(y_ts, mlpc.predict_proba(X_ts)[:,1])
# Out:
# 0.9995516422577172

# %%
fpr, tpr, ths = roc_curve(y_ts, mlpc.predict_proba(X_ts)[:,1])
plt.figure(figsize=(7,7))
plt.plot(fpr,tpr,'k-')
plt.plot((0,1),(0,1),'k--');

# %%
loss = mlpc.best_estimator_.loss_curve_
plt.figure(figsize=(15,5))
plt.plot(loss, 'o-')
plt.xticks(np.arange(19));

# %%
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print(validation)

# %%
prediction = list(mlpc.predict(X_val_padronizado[start:end]))
# print(prediction)

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    mlpc_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# ---
# 15 tipo(s) de vinho(s) NÃO previstos corretamente!
# ---
# prediction
# 0    15
# Name: count, dtype: int64
# ---
#     seq  validation  prediction
# 10  390           1           0
# 11  406           1           0
# 12  532           1           0
# 13  568           1           0
# 14  582           1           0

# %%
# MATRIZ CONFUSÃO - df Validação
mlpc_y_pred_val = mlpc.predict(X_val_padronizado)
confusion_matrix(y_val, mlpc_y_pred_val)
# Out:
# array([[158,   0],
#        [ 15, 412]], dtype=int64)

# %% [markdown]
# <a name="rna"></a>
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             TensorFlow
#         </b>
#     <br/>&nbsp;
# </center>

# %%
# Desativar os avisos
import warnings
warnings.filterwarnings('ignore')

# %%
# ESTUDAR ESSE MODELO COM MAIS ATENÇÃO!
# VERIFICAR OS PARAMETROS
# TESTAR A BASE COM O PRÉ-PROESSAMENTO DO KERAS

# Criando o modelo da rede neural
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(X_tr.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compilando o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Treinando o modelo
model.fit(X_tr, y_tr, epochs=10, batch_size=32, validation_data=(X_ts, y_ts))
# Out:
# WARNING:tensorflow:From C:\Users\geanc\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\geanc\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\geanc\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\geanc\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 170/170 [==============================] - 3s 4ms/step - loss: 0.1018 - accuracy: 0.9786 - val_loss: 0.0450 - val_accuracy: 0.9914
# Epoch 2/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9936 - val_loss: 0.0362 - val_accuracy: 0.9914
# Epoch 3/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9943 - val_loss: 0.0280 - val_accuracy: 0.9931
# Epoch 4/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 0.0254 - val_accuracy: 0.9940
# Epoch 5/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 0.0225 - val_accuracy: 0.9948
# Epoch 6/10
# 170/170 [==============================] - 1s 4ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.0220 - val_accuracy: 0.9948
# Epoch 7/10
# 170/170 [==============================] - 1s 5ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.0199 - val_accuracy: 0.9953
# Epoch 8/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0182 - val_accuracy: 0.9953
# Epoch 9/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.0169 - val_accuracy: 0.9961
# Epoch 10/10
# 170/170 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0164 - val_accuracy: 0.9953

# %%
# Avaliar o modelo nos dados de teste
evaluation = model.evaluate(X_ts, y_ts)

# Fazer previsões usando o modelo nos dados de teste
predictions = model.predict(X_ts)
predicted_labels = (predictions > 0.5).astype("int32")  # Se for um modelo de classificação binária

# Calcular métricas
model_precision = precision_score(y_ts, predicted_labels)
model_recall = recall_score(y_ts, predicted_labels)
model_f1_score = f1_score(y_ts, predicted_labels)

# Imprimir métricas
print("Perda (Loss):", evaluation[0])
print("Acurácia (Accuracy):", evaluation[1])
print("Precisão (Precision):", model_precision)
print("Recall:", model_recall)
print("F1-score:", model_f1_score)
# Out:
# 73/73 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 0.9953
# 73/73 [==============================] - 0s 1ms/step
# Perda (Loss): 0.016438646242022514
# Acurácia (Accuracy): 0.995276927947998
# Precisão (Precision): 0.9931623931623932
# Recall: 0.9974248927038627
# F1-score: 0.9952890792291221

# %%
start, end = 0, X_val_padronizado.shape[0]
validation = list(y_val[start:end].values)
# print(validation)

# %%
probabilidades = model.predict(X_val_padronizado[start:end])

# Definindo um limiar
limiar = 0.5

# Convertendo probabilidades em rótulos (0 ou 1) com base no limiar
prediction = [1 if prob >= limiar else 0 for prob in probabilidades]

# print(prediction)
# Out:
# 19/19 [==============================] - 0s 866us/step

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    tf_y_val = dfp.prediction.shape[0]
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))
# Out:
# 585 registros lidos
# ---
# 24 tipo(s) de vinho(s) NÃO previstos corretamente!
# ---
# prediction
# 0    24
# Name: count, dtype: int64
# ---
#     seq  validation  prediction
# 19  426           1           0
# 20  451           1           0
# 21  473           1           0
# 22  568           1           0
# 23  582           1           0

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Combinação de Modelos
#         </b>
#     <br/>&nbsp;
# </center>

# %%
# QUANDO POSSÍVEL TESTAR E ESTUDAR MELHOR ESSA FUNÇÃO
# Este algorítmo está atralado com a diversidade dos dados para gerar multiplos modelos
# de um mesmo modelo (exemplo: várias versões do KNN) e chegar ao de melhor avaliação final
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html
# Bagging
# from sklearn.ensemble import BaggingClassifier

# %%
validacao = RepeatedKFold(n_splits = 10, n_repeats = 3)
# validacao = RepeatedStratifiedKFold(n_splits = 10, n_repeats = 3)
model = [('LogisticRegression', rfc), ('KNeighborsClassifier', neigh), ('ExtraTreesClassifier', etc)]
combined_model = VotingClassifier(model, voting = 'hard')
medidas = cross_validate(combined_model, X_tr, y_tr, cv = validacao, scoring = 'accuracy')
round(medidas['test_score'].mean(), 4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[181], line 5
#       3 model = [('LogisticRegression', rfc), ('KNeighborsClassifier', neigh), ('ExtraTreesClassifier', etc)]
#       4 combined_model = VotingClassifier(model, voting = 'hard')
# ----> 5 medidas = cross_validate(combined_model, X_tr, y_tr, cv = validacao, scoring = 'accuracy')
#       6 round(medidas['test_score'].mean(), 4)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_voting.py:346, in VotingClassifier.fit(self, X, y, sample_weight)
#     343 self.classes_ = self.le_.classes_
#     344 transformed_y = self.le_.transform(y)
# --> 346 return super().fit(X, transformed_y, sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_voting.py:81, in _BaseVoting.fit(self, X, y, sample_weight)
#      75 if self.weights is not None and len(self.weights) != len(self.estimators):
#      76     raise ValueError(
#      77         "Number of `estimators` and weights must be equal; got"
#      78         f" {len(self.weights)} weights, {len(self.estimators)} estimators"
#      79     )
# ---> 81 self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#      82     delayed(_fit_single_estimator)(
#      83         clone(clf),
#      84         X,
#      85         y,
#      86         sample_weight=sample_weight,
#      87         message_clsname="Voting",
#      88         message=self._log_message(names[idx], idx + 1, len(clfs)),
#      89     )
#      90     for idx, clf in enumerate(clfs)
#      91     if clf != "drop"
#      92 )
#      94 self.named_estimators_ = Bunch()
#      96 # Uses 'drop' as placeholder for dropped estimators
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:46, in _fit_single_estimator(estimator, X, y, sample_weight, message_clsname, message)
#      44 else:
#      45     with _print_elapsed_time(message_clsname, message):
# ---> 46         estimator.fit(X, y)
#      47 return estimator
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:462, in BaseForest.fit(self, X, y, sample_weight)
#     457 if self.warm_start and len(self.estimators_) > 0:
#     458     # We draw from the random state to get the random state we
#     459     # would have got if we hadn't used a warm_start.
#     460     random_state.randint(MAX_INT, size=len(self.estimators_))
# --> 462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
#     473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#    (...)
#     490     for i, t in enumerate(trees)
#     491 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:463, in <listcomp>(.0)
#     457 if self.warm_start and len(self.estimators_) > 0:
#     458     # We draw from the random state to get the random state we
#     459     # would have got if we hadn't used a warm_start.
#     460     random_state.randint(MAX_INT, size=len(self.estimators_))
#     462 trees = [
# --> 463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
#     473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#    (...)
#     490     for i, t in enumerate(trees)
#     491 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:192, in BaseEnsemble._make_estimator(self, append, random_state)
#     186 def _make_estimator(self, append=True, random_state=None):
#     187     """Make and configure a copy of the `estimator_` attribute.
#     188
#     189     Warning: This method should be used to properly instantiate new
#     190     sub-estimators.
#     191     """
# --> 192     estimator = clone(self.estimator_)
#     193     estimator.set_params(**{p: getattr(self, p) for p in self.estimator_params})
#     195     # TODO(1.3): Remove
#     196     # max_features = 'auto' would cause warnings in every call to
#     197     # Tree.fit(..)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:87, in clone(estimator, safe)
#      79             raise TypeError(
#      80                 "Cannot clone object '%s' (type %s): "
#      81                 "it does not seem to be a scikit-learn "
#      82                 "estimator as it does not implement a "
#      83                 "'get_params' method." % (repr(estimator), type(estimator))
#      84             )
#      86 klass = estimator.__class__
# ---> 87 new_object_params = estimator.get_params(deep=False)
#      88 for name, param in new_object_params.items():
#      89     new_object_params[name] = clone(param, safe=False)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:169, in BaseEstimator.get_params(self, deep)
#     154 """
#     155 Get parameters for this estimator.
#     156
#    (...)
#     166     Parameter names mapped to their values.
#     167 """
#     168 out = dict()
# --> 169 for key in self._get_param_names():
#     170     value = getattr(self, key)
#     171     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:134, in BaseEstimator._get_param_names(cls)
#     130     return []
#     132 # introspect the constructor arguments to find the model parameters
#     133 # to represent
# --> 134 init_signature = inspect.signature(init)
#     135 # Consider the constructor parameters excluding 'self'
#     136 parameters = [
#     137     p
#     138     for p in init_signature.parameters.values()
#     139     if p.name != "self" and p.kind != p.VAR_KEYWORD
#     140 ]
#
# File ~\anaconda3\Lib\inspect.py:3280, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3278 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3279     """Get a signature object for the passed callable."""
# -> 3280     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3281                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~\anaconda3\Lib\inspect.py:3028, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3024 @classmethod
#    3025 def from_callable(cls, obj, *,
#    3026                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3027     """Constructs Signature for the given callable object."""
# -> 3028     return _signature_from_callable(obj, sigcls=cls,
#    3029                                     follow_wrapper_chains=follow_wrapped,
#    3030                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~\anaconda3\Lib\inspect.py:2516, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2511             return sig.replace(parameters=new_params)
#    2513 if isfunction(obj) or _signature_is_functionlike(obj):
#    2514     # If it's a pure Python function, or an object that is duck type
#    2515     # of a Python function (Cython functions, for instance), then:
# -> 2516     return _signature_from_function(sigcls, obj,
#    2517                                     skip_bound_arg=skip_bound_arg,
#    2518                                     globals=globals, locals=locals, eval_str=eval_str)
#    2520 if _signature_is_builtin(obj):
#    2521     return _signature_from_builtin(sigcls, obj,
#    2522                                    skip_bound_arg=skip_bound_arg)
#
# File ~\anaconda3\Lib\inspect.py:2378, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2376 kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2377 annotation = annotations.get(name, _empty)
# -> 2378 parameters.append(Parameter(name, annotation=annotation,
#    2379                             kind=kind))
#    2380 if posonly_left:
#    2381     posonly_left -= 1
#
# File ~\anaconda3\Lib\inspect.py:2688, in Parameter.__init__(self, name, kind, default, annotation)
#    2686 def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2687     try:
# -> 2688         self._kind = _ParameterKind(kind)
#    2689     except ValueError:
#    2690         raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#
# KeyboardInterrupt:

# %%
combined_model.fit(X_tr, y_tr)

# %%
validation[:20]

# %%
prediction = list(combined_model.predict(X_val_padronizado[start:end]))
# print(prediction)

# %%
prediction[:20]

# %%
if (validation != prediction): 
    # imprimir dataframe com PREVISÃO diferente da variável real de referência
    resultados = []
    for i, (a, b) in enumerate(zip(validation, prediction)):
        if a != b:
    #         print(f"Posição {i}: {a} != {b}")
            resultados.append([i, a, b])
    dfp = pd.DataFrame(resultados, columns=["seq", "validation", "prediction"])
    print(f'{len(prediction)} registros lidos')
    print('---')
    print(f'{dfp.prediction.shape[0]} tipo(s) de vinho(s) NÃO previstos corretamente!')
    print('---')
    print(dfp.prediction.value_counts())
    print('---')
    display(dfp.tail())
else:    
    print(f'O modelo previu corretamente os resultados em relação a variável "y"')
    print(list(set(validation) - set(prediction)))

# %%
# MATRIZ CONFUSÃO - df Validação
combined_model_y_pred_val = combined_model.predict(X_val_padronizado)
confusion_matrix(y_val, combined_model_y_pred_val)

# %% [markdown]
# <center style="font-size:18pt; background-color:#DF1C44">
#     <br/>
#         <b style="color: #ffffff">
#             Métricas - modelos de classificação
#         </b>
#     <br/>&nbsp;
# </center>

# %%
# data frame modelos
dfm = {
    'modelo':['Extra Trees Classifier', 'KNeighbors Classifier', 'Decision Tree Classifier',
              'Logistic Regression', 'Random Forest Classifier', 'Neural Network MLPC', 'TensorFlow'],
    'accuracy':[etc_acuracia,neigh_acuracia,dtc_acuracia,lr_acuracia, rfc_acuracia, mlpc_acuracia, evaluation[1]],
    'recall':[etc_recall,neigh_recall,dtc_recall, lr_recall, rfc_recall, mlpc_recall, model_recall],
    'precision':[etc_precision,neigh_precision,dtc_precision, lr_precision, rfc_precision, mlpc_precision, model_precision],
    'f1_score':[etc_f1_score,neigh_f1_score,dtc_f1_score,lr_f1_score, rfc_f1_score, mlpc_f1_score, model_f1_score],
    'ERROS de predição': [etc_y_val, neigh_y_val, dtc_y_val, lr_y_val, rfc_y_val, mlpc_y_val, tf_y_val]
    }    
modelos = pd.DataFrame(dfm)

# %%
# Análise de perfomance de cada modelo em relação as métrica da matrix confusão
modelos.style.highlight_max(subset=list(modelos.columns.drop(['modelo','ERROS de predição'])))
# Out:
# <style type="text/css">
# #T_8a9d9_row3_col2, #T_8a9d9_row6_col1, #T_8a9d9_row6_col3, #T_8a9d9_row6_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8a9d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9d9_level0_col0" class="col_heading level0 col0" >modelo</th>
#       <th id="T_8a9d9_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_8a9d9_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_8a9d9_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_8a9d9_level0_col4" class="col_heading level0 col4" >f1_score</th>
#       <th id="T_8a9d9_level0_col5" class="col_heading level0 col5" >ERROS de predição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a9d9_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_8a9d9_row0_col1" class="data row0 col1" >0.992701</td>
#       <td id="T_8a9d9_row0_col2" class="data row0 col2" >0.996567</td>
#       <td id="T_8a9d9_row0_col3" class="data row0 col3" >0.988927</td>
#       <td id="T_8a9d9_row0_col4" class="data row0 col4" >0.992732</td>
#       <td id="T_8a9d9_row0_col5" class="data row0 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a9d9_row1_col0" class="data row1 col0" >KNeighbors Classifier</td>
#       <td id="T_8a9d9_row1_col1" class="data row1 col1" >0.987978</td>
#       <td id="T_8a9d9_row1_col2" class="data row1 col2" >0.984549</td>
#       <td id="T_8a9d9_row1_col3" class="data row1 col3" >0.991357</td>
#       <td id="T_8a9d9_row1_col4" class="data row1 col4" >0.987941</td>
#       <td id="T_8a9d9_row1_col5" class="data row1 col5" >23</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a9d9_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_8a9d9_row2_col1" class="data row2 col1" >0.983255</td>
#       <td id="T_8a9d9_row2_col2" class="data row2 col2" >0.987983</td>
#       <td id="T_8a9d9_row2_col3" class="data row2 col3" >0.978741</td>
#       <td id="T_8a9d9_row2_col4" class="data row2 col4" >0.983340</td>
#       <td id="T_8a9d9_row2_col5" class="data row2 col5" >62</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a9d9_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_8a9d9_row3_col1" class="data row3 col1" >0.993559</td>
#       <td id="T_8a9d9_row3_col2" class="data row3 col2" >0.998283</td>
#       <td id="T_8a9d9_row3_col3" class="data row3 col3" >0.988946</td>
#       <td id="T_8a9d9_row3_col4" class="data row3 col4" >0.993592</td>
#       <td id="T_8a9d9_row3_col5" class="data row3 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a9d9_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_8a9d9_row4_col1" class="data row4 col1" >0.990983</td>
#       <td id="T_8a9d9_row4_col2" class="data row4 col2" >0.995708</td>
#       <td id="T_8a9d9_row4_col3" class="data row4 col3" >0.986395</td>
#       <td id="T_8a9d9_row4_col4" class="data row4 col4" >0.993592</td>
#       <td id="T_8a9d9_row4_col5" class="data row4 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8a9d9_row5_col0" class="data row5 col0" >Neural Network MLPC</td>
#       <td id="T_8a9d9_row5_col1" class="data row5 col1" >0.994418</td>
#       <td id="T_8a9d9_row5_col2" class="data row5 col2" >0.997425</td>
#       <td id="T_8a9d9_row5_col3" class="data row5 col3" >0.991468</td>
#       <td id="T_8a9d9_row5_col4" class="data row5 col4" >0.994437</td>
#       <td id="T_8a9d9_row5_col5" class="data row5 col5" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8a9d9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8a9d9_row6_col0" class="data row6 col0" >TensorFlow</td>
#       <td id="T_8a9d9_row6_col1" class="data row6 col1" >0.995277</td>
#       <td id="T_8a9d9_row6_col2" class="data row6 col2" >0.997425</td>
#       <td id="T_8a9d9_row6_col3" class="data row6 col3" >0.993162</td>
#       <td id="T_8a9d9_row6_col4" class="data row6 col4" >0.995289</td>
#       <td id="T_8a9d9_row6_col5" class="data row6 col5" >24</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Análise de erros de predição de cada modelo em relação ao dados do mundo real
modelos.style.highlight_min(subset=list(modelos.columns.drop(['modelo', 'accuracy', 'recall', 'precision', 'f1_score'])))
# Out:
# <style type="text/css">
# #T_2f243_row0_col5, #T_2f243_row4_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2f243">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f243_level0_col0" class="col_heading level0 col0" >modelo</th>
#       <th id="T_2f243_level0_col1" class="col_heading level0 col1" >accuracy</th>
#       <th id="T_2f243_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_2f243_level0_col3" class="col_heading level0 col3" >precision</th>
#       <th id="T_2f243_level0_col4" class="col_heading level0 col4" >f1_score</th>
#       <th id="T_2f243_level0_col5" class="col_heading level0 col5" >ERROS de predição</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f243_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f243_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_2f243_row0_col1" class="data row0 col1" >0.992701</td>
#       <td id="T_2f243_row0_col2" class="data row0 col2" >0.996567</td>
#       <td id="T_2f243_row0_col3" class="data row0 col3" >0.988927</td>
#       <td id="T_2f243_row0_col4" class="data row0 col4" >0.992732</td>
#       <td id="T_2f243_row0_col5" class="data row0 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2f243_row1_col0" class="data row1 col0" >KNeighbors Classifier</td>
#       <td id="T_2f243_row1_col1" class="data row1 col1" >0.987978</td>
#       <td id="T_2f243_row1_col2" class="data row1 col2" >0.984549</td>
#       <td id="T_2f243_row1_col3" class="data row1 col3" >0.991357</td>
#       <td id="T_2f243_row1_col4" class="data row1 col4" >0.987941</td>
#       <td id="T_2f243_row1_col5" class="data row1 col5" >23</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2f243_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_2f243_row2_col1" class="data row2 col1" >0.983255</td>
#       <td id="T_2f243_row2_col2" class="data row2 col2" >0.987983</td>
#       <td id="T_2f243_row2_col3" class="data row2 col3" >0.978741</td>
#       <td id="T_2f243_row2_col4" class="data row2 col4" >0.983340</td>
#       <td id="T_2f243_row2_col5" class="data row2 col5" >62</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2f243_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_2f243_row3_col1" class="data row3 col1" >0.993559</td>
#       <td id="T_2f243_row3_col2" class="data row3 col2" >0.998283</td>
#       <td id="T_2f243_row3_col3" class="data row3 col3" >0.988946</td>
#       <td id="T_2f243_row3_col4" class="data row3 col4" >0.993592</td>
#       <td id="T_2f243_row3_col5" class="data row3 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2f243_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_2f243_row4_col1" class="data row4 col1" >0.990983</td>
#       <td id="T_2f243_row4_col2" class="data row4 col2" >0.995708</td>
#       <td id="T_2f243_row4_col3" class="data row4 col3" >0.986395</td>
#       <td id="T_2f243_row4_col4" class="data row4 col4" >0.993592</td>
#       <td id="T_2f243_row4_col5" class="data row4 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2f243_row5_col0" class="data row5 col0" >Neural Network MLPC</td>
#       <td id="T_2f243_row5_col1" class="data row5 col1" >0.994418</td>
#       <td id="T_2f243_row5_col2" class="data row5 col2" >0.997425</td>
#       <td id="T_2f243_row5_col3" class="data row5 col3" >0.991468</td>
#       <td id="T_2f243_row5_col4" class="data row5 col4" >0.994437</td>
#       <td id="T_2f243_row5_col5" class="data row5 col5" >15</td>
#     </tr>
#     <tr>
#       <th id="T_2f243_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2f243_row6_col0" class="data row6 col0" >TensorFlow</td>
#       <td id="T_2f243_row6_col1" class="data row6 col1" >0.995277</td>
#       <td id="T_2f243_row6_col2" class="data row6 col2" >0.997425</td>
#       <td id="T_2f243_row6_col3" class="data row6 col3" >0.993162</td>
#       <td id="T_2f243_row6_col4" class="data row6 col4" >0.995289</td>
#       <td id="T_2f243_row6_col5" class="data row6 col5" >24</td>
#     </tr>
#   </tbody>
# </table>
